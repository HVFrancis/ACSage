# %% [markdown]
# ## Lab 2 - The Second Derivative

# %% [markdown]
# Names:

# %% [markdown]
# ### Calculus Overview
#
# This lab activity primarily concerns the second derivative of a function: in particular, given a function $f$, we want to not only be able to understand its derivative, $f'$ , but also its second derivative, $f''$ .  In most of what follows, we will work graphically and use SageMath to check our work.

# %% [markdown]
# ### Problem 1
# Prelab: If you haven't already, work Preview Activity 1.6.1. Have that on paper to go over with your lab partner(s) at the beginning of class, and to be collected sometime during lab.

# %% [markdown]
# ### Problem 2
#
# Let $m(x) = 3+\frac{2}{x + 1}$
#
# a. In Lab 3, you found that $m'(x) = \frac{-2}{(x+1)^2}$. In the cell below, generate a plot of $m'(x)$ on the interval $[-4, 2]$ (Remember to set reasonable values for `ymin` and `ymax` to see the graph clearly.)

# %% [markdown]
# b. On separate paper (perhaps on the back of your prelab), using the graph of $m'(x)$, work by hand to sketch a plot of the graph of $m''(x)$.  Type a sentence below to explain why you think your graph looks as you’ve drawn it.

# %% [markdown]
# Answer to b:

# %% [markdown]
# c. Write instructions to create a plot of $m''(x)$ in the cell below. Remember, if you called $m'(x)$ `mprime(x) = (-2)/((x+1)^2)` you can make `mprimeprime(x) = mprime(x).diff()` and then do `plot(mprimeprime)` (adding additional options to the plot functions as needed to frame the graph well)

# %% [markdown]
# Does the graph you made by hand match the one generated by SageMath?
#
# Explain:

# %% [markdown]
# d. Finally, complete the following sentence by filling in the blanks appropriately:
#
# “The function $m$ is concave up on the interval _ because its derivative, $m'$ , is _ on the interval _, and consequently its second derivative is _ on this same interval.”
#
# Write a similar sentence regarding where m is concave down.

# %% [markdown]
# ---
#
# ### Problem 3
#
# Let $f(x) = e^{-x^2}(x^4 - 2x^2 +1)$
#
# a. Have Sagemath generate a plot of $f$ on the interval $[-3, 3]$

# %%
f(x) = exp(-x^2)*(x^4 - 2*x^2 + 1)
plot(f, (x, -3, 3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# b. Working by hand, sketch plots of $f'$ and $f''$. Then check your by-hand work by having SageMath generate the appropriate plots.

# %% [markdown]
# c. Write several sentences to describe how the concavity of $f$ is connected to the behavior of its first and second derivatives.

# %% [markdown]
# Answer:

# %% [markdown]
# d. We can use `f` to create a function for estimating the derivative (with $h = 0.1$) using the central difference formula...

# %%
h = 0.1
fprimecd(x) = (f(x+h) - f(x-h))/(2*h)

# %% [markdown]
# ... then use it to estimate $f'(0.4)$...

# %%
fprimecd(0.4)
# Out:
# -1.59375487022719

# %% [markdown]
# Use this to estimate $f'(0.5)$ and $f'(0.6)$

# %% [markdown]
# e. Finally use your answers in part d to estimate $f''(0.5)$ with $h=0.1$. (Note, you do NOT need to find `fprime(x)=f.diff()` to answer this. Simply make use of the estimates of $f'(0.4)$ and $f'(0.6)$ appropriately!)

# %% [markdown]
# How is the value you find consistent with your work in (b) and (c) above?

# %% [markdown]
# Answer:

# %% [markdown]
# ---
# ### Problem 4
#
# Let $p(x) = x^2 - 3x$
#
# a. In Lab 1, you found that $p'(x) = 2x -3$
#
# Write a sentence that uses key calculus terminology to describe the behavior of $p'$ as $x$ increases.  What does the behavior of $p'$ tell you about the concavity of the function $p$?

# %% [markdown]
# Answer:

# %% [markdown]
# b. Create SageMath functions for $p$ and $p'$ below, and plot them on the same graph

# %% [markdown]
# c. Observe that $p'$ is a linear function.  Without using the limit definition, determine a formula for $p''$.  What can you say about the sign of $p''$ for every value of $x$?  How is this observation consistent with your conclusion(s) in (a)?

# %% [markdown]
# Answer:
