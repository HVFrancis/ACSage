# %%
s(x) = 64 - 16*(x-1)^2
plot(s, (x, 0.99, 1.01), aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g(x) = sin(pi/x)
plot(g, xmin=-0.01, xmax=0.01)
# Out:
# Graphics object consisting of 1 graphics primitive
