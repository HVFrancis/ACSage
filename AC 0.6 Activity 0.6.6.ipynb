# %%
V1(x) = 30*cos(100*pi*x - 0.013) + 20
V2(x) = 30*cos(100*pi*(x - 0.013)) + 20
V2.plot((x, 0, 0.05))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x) = (x + 3)/(5*x - 2)
f.plot(ymin=-1, ymax = 1, xmin=-10, xmax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
h(x) = (x+1)/(x^2 + 2*x - 1)
h.plot(ymin=-1, ymax = 1, xmin=-10, xmax=10)
# Out:
# Graphics object consisting of 1 graphics primitive
